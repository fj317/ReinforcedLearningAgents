# %% [markdown]
# ## The Racetrack Environment
# We have implemented a custom environment called "Racetrack" for you to use during this piece of coursework. It is inspired by the environment described in the course textbook (Reinforcement Learning, Sutton & Barto, 2018, Exercise 5.12), but is not exactly the same.
#
# ### Environment Description
# Consider driving a race car around a turn on a racetrack. In order to complete the race as quickly as possible, you would want to drive as fast as you can but, to avoid running off the track, you must slow down while turning.
#
# In our simplified racetrack environment, the agent is at one of a discrete set of grid positions. The agent also has a discrete speed in two directions, $x$ and $y$. So the state is represented as follows:
# $$(\text{position}_y, \text{position}_x, \text{velocity}_y, \text{velocity}_x)$$
#
# The agent collects a reward of -1 at each time step, an additional -10 for leaving the track (i.e., ending up on a black grid square in the figure below), and an additional +10 for reaching the finish line (any of the red grid squares). The agent starts each episode on a randomly selected grid-square on the starting line (green grid squares) with a speed of zero in both directions. At each time step, the agent can change its speed in both directions. Each speed can be changed by +1, -1 or 0, giving a total of nine actions. For example, the agent may increase its speed in the $x$ direction by -1 and its speed in the $y$ direction by +1. The agent's speed cannot be greater than +10 or less than -10 in either direction.
#
# <img src="images/track_big.png" style="width: 600px;"/>
#
#
# The agent's next state is determined by its current grid square, its current speed in two directions, and the changes it  makes to its speed in the two directions. This environment is stochastic. When the agent tries to change its speed, no change occurs (in either direction) with probability 0.2. In other words, 20% of the time, the agent's action is ignored and the car's speed remains the same in both directions.
#
# If the agent leaves the track, it is returned to a random start grid-square and has its speed set to zero in both directions; the episode continues. An episode ends only when the agent transitions to a goal grid-square.
#
#
#
# ### Environment Implementation
# We have implemented the above environment in the `racetrack_env.py` file, for you to use in this coursework. Please use this implementation instead of writing your own, and please do not modify the environment.
#
# We provide a `RacetrackEnv` class for your agents to interact with. The class has the following methods:
# - **`reset()`** - this method initialises the environment, chooses a random starting state, and returns it. This method should be called before the start of every episode.
# - **`step(action)`** - this method takes an integer action (more on this later), and executes one time-step in the environment. It returns a tuple containing the next state, the reward collected, and whether the next state is a terminal state.
# - **`render(sleep_time)`** - this method renders a matplotlib graph representing the environment. It takes an optional float parameter giving the number of seconds to display each time-step. This method is useful for testing and debugging, but should not be used during training since it is *very* slow. **Do not use this method in your final submission**.
# - **`get_actions()`** - a simple method that returns the available actions in the current state. Always returns a list containing integers in the range [0-8] (more on this later).
#
# In our code, states are represented as Python tuples - specifically a tuple of four integers. For example, if the agent is in a grid square with coordinates ($Y = 2$, $X = 3$), and is moving zero cells vertically and one cell horizontally per time-step, the state is represented as `(2, 3, 0, 1)`. Tuples of this kind will be returned by the `reset()` and `step(action)` methods. It is worth noting that tuples can be used to index certain Python data-structures, such as dictionaries.
#
# There are nine actions available to the agent in each state, as described above. However, to simplify your code, we have represented each of the nine actions as an integer in the range [0-8]. The table below shows the index of each action, along with the corresponding changes it will cause to the agent's speed in each direction.
#
# <img src="images/action_grid.png" style="width: 250px;"/>
#
# For example, taking action 8 will increase the agent's speed in the $x$ direction, but decrease its speed in the $y$ direction.

# %% [markdown]
# ## Exercise 1: On-Policy MC Control (6 Marks)
#
# In this exercise, you will implement an agent which learns to reach a goal state in the racetrack task using On-Policy First-Visit MC Control, the pseudocode for which is reproduced below (Reinforcement Learning, Sutton & Barto, 2018, Section 5.4 p.101).
#
# <img src="images/mc_control_algo.png" style="width: 650px;"/>
#
# Please use the following parameter settings:
# - Discount factor $\gamma = 0.9$.
# - For your $\epsilon$-greedy policy, use exploratory action probability $\epsilon = 0.15$.
# - Number of training episodes $= 150$.
# - Number of agents averaged should be at **least** 20.
#
#
# Your implementation of a tabular **On-Policy First-Visit MC Control** agent should produce a list named `mc_rewards`. This list should contain one list for each agent that you train. Each sub-list should contain the undiscounted sum of rewards earned during each episode by the corresponding agent. <br />

# %%
# You should implement your MC agent and plot your average learning curve here.
import random
from racetrack_env import RacetrackEnv
from statistics import mean
import numpy as np
import random
import pprint
from collections import defaultdict
import matplotlib.pyplot as plt
random.seed(5)

# %%
# given a policy, return an episode
def generateEpisode(policy):
    currState = env.reset()
    episode = []
    reward = None
    terminal = False
    while terminal == False:
        actionIndex = dictionaryRandomChoice(policy, currState)
        episode.append([currState, actionIndex, reward])
        currState, reward, terminal = env.step(actionIndex)
    episode.append([currState, None, reward])
    return episode

# find the action that returns the max QValue
def findMaxAction(Q, state):
    QValues = []
    for i in range(9):
        QValues.append(Q[state, i])
    bestAction = QValues.index(max(QValues))
    return bestAction

# goes through each action for a state in the dictionary and chooses an action based on probabilities
def dictionaryRandomChoice(policy, state):
    probs = []
    for i in range (9):
        probs.append(policy[state, i])
    action = np.random.choice(9, p = probs)
    return action

# generate the policy
def generatePolicy():
    policy = {}
    # goes through every single possible (state, action) and adds to the policy with default probability of 1/9 (equal prob for each action)
    for x in range(1, 14):
        for y in range(1, 18):
            for speedx in range(-10, 11):
                for speedy in range(-10, 11):
                    for action in range(9):
                        # set equal prob for each action at start
                        policy[(x, y, speedx, speedy), action] = 1/9
    return policy

# check if a (state, action) exists in a episode already
def checkExists(episode, state, action):
    for i in range (len(newEpisode)):
        if state in newEpisode[i][0] and action in newEpisode[i][1]:
            return True
    return False

# %%
env = RacetrackEnv()
# Initialise/reset environment.
mc_rewards = []
𝛾 = 0.9
𝜖 = 0.15
episodeNumber = 150
agentNumber = 20
print("Ready!")
# Out:
# Ready!

# %%
print("Starting")
for currAgent in range (agentNumber):
    print("New agent learning ", currAgent)
    # reinitialise agent specific variables (returns, number of times state reached, Q and policy)
    returns = defaultdict(float)
    N = defaultdict(int)
    Q = defaultdict(float)
    policy = generatePolicy()
    mc_rewards.append([])
    for currEpisode in range (episodeNumber):
        if currEpisode % 10 == 0:
            print("Episode ", currEpisode)
        mc_rewards[currAgent].append(0)
        episode = generateEpisode(policy)
        # remove reward from episode
        # also remove last state, action pair (i.e. the current one) to see if it exists elsewhere in the episode
        newEpisode = np.asarray(episode)[0:len(episode) - 2,[0, 1]]
        G = 0
        # iterate through episode, starting at end
        for t in range (len(episode) - 2, 0, -1):            
            # get state, action, reward into variables for easy access
            state = episode[t][0]
            action = episode[t][1]
            reward = episode[t+1][2]
            # calculate return
            G = 𝛾 * G + reward
            mc_rewards[currAgent][currEpisode] += reward
            # check if state, action already in episode before
            if not checkExists(newEpisode, state, action):
                # add to returns list
                returns[state, action] += G
                N[state, action] += 1 
                # find average
                Q[state, action] = returns[state, action] / N[state, action]
                actionIndex = findMaxAction(Q, state)
                # go thru each action and check if matches, calculate probs
                for i in range(9):
                    if i == actionIndex:
                        policy[state, i] = 1 - 𝜖 + (𝜖/9)
                    else:
                        policy[state, i] = 𝜖/9
            # copy the view of array - https://stackoverflow.com/a/32932959
            newEpisode = newEpisode[:-1].copy()
print("Fin")
# Out:
# Starting
# New agent learning  0
# Episode  0
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  1
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  2
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  3
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  4
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  5
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  6
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  7
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  8
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  9
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  10
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  11
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  12
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  13
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  14
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  15
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  16
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  17
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  18
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  19
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# Fin

# %%
from racetrack_env import plot_results
from racetrack_env import simple_issue_checking

# Checking MC Control Results for Obvious Issues.
simple_issue_checking(mc_rewards)

# Plotting MC Control Learning Curve.
# %matplotlib inline
plot_results(mc_rewards = mc_rewards)

# %% [markdown]
# ## Exercise 2: Sarsa (3 Marks)
#
# In this exercise, you will implement an agent which learns to reach a goal state in the racetrack task using the Sarsa algorithm, the pseudocode for which is reproduced below (Reinforcement Learning, Sutton & Barto, 2018, Section 6.4 p.129).
#
# <img src="images/sarsa_algo.png" style="width: 650px;"/>
#
# Please use the following parameter settings:
# - Step size parameter $\alpha = 0.2$.
# - Discount factor $\gamma = 0.9$.
# - For your $\epsilon$-greedy policy, use exploratory action probability $\epsilon = 0.15$.
# - Number of training episodes $= 150$.
# - Number of agents averaged should be at **least** 20.
#
#
# Your implementation of a tabular **Sarsa** agent should produce a list named `sarsa_rewards`. This list should contain one list for each agent that you train. Each sub-list should contain the undiscounted sum of rewards earned during each episode by the corresponding agent. <br />

# %%
env = RacetrackEnv()

# Initialise/reset environment.
sarsa_rewards = []
𝛾 = 0.9
𝜖 = 0.15
𝛼 = 0.2
episodeNumber = 150
agentNumber = 20
print("Ready!")
# Out:
# Ready!

# %%
def chooseAction(Q, state):
    # using Q, derive action for current state
    # decide if explore action or greedy action
    if np.random.uniform(0, 1) < 𝜖:
        # explore action
        return np.random.randint(0, 9)
    # greedy action
    # loop through each action and find best action in current state
    QValues = []
    for i in range(9):
        QValues.append(Q[state, i])
    bestAction = QValues.index(max(QValues))
    return bestAction

for agent in range(agentNumber):
    print("New agent learning ", agent)
    # initalise agent specific variable (Q values for state, action)
    Q = defaultdict(float)
    sarsa_rewards.append([])
    for episode in range(episodeNumber):
        if episode % 10 == 0:
            print("Episode ", episode)
        sarsa_rewards[agent].append(0)
        state = env.reset()
        terminal = False
        action = chooseAction(Q, state)
        # choose action from policy
        while terminal == False:
            newState, reward, terminal = env.step(action)
            sarsa_rewards[agent][episode] += reward
            newAction = chooseAction(Q, newState)
            # update q value for state, action
            Q[state, action] = round(Q[state, action] + 𝛼*(reward + 𝛾*Q[newState, newAction] - Q[state, action]), 2)
            state = newState
            action = newAction
            
print("Fin")
# Out:
# New agent learning  0
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  1
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  2
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  3
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  4
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  5
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  6
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  7
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  8
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  9
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  10
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  11
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  12
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  13
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  14
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  15
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  16
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  17
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  18
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  19
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# Fin

# %%
from racetrack_env import plot_results
from racetrack_env import simple_issue_checking

# Checking Sarsa Results for Obvious Issues.
simple_issue_checking(sarsa_rewards)

# Plotting Sarsa Learning Curve.
# %matplotlib inline
plot_results(sarsa_rewards = sarsa_rewards)

# %% [markdown]
# ## Exercise 3: Q-Learning (3 Marks)
#
# In this exercise, you will implement an agent which learns to reach a goal state in the racetrack task using the Q-Learning algorithm, the pseudocode for which is reproduced below (Reinforcement Learning, Sutton & Barto, 2018, Section 6.5 p.131).
#
# <img src="images/q_learning_algo.png" style="width: 650px;"/>
#
# Please use the following parameter settings:
# - Step size parameter $\alpha = 0.2$.
# - Discount factor $\gamma = 0.9$.
# - For your $\epsilon$-greedy policy, use exploratory action probability $\epsilon = 0.15$.
# - Number of training episodes $= 150$.
# - Number of agents averaged should be at **least** 20.
#
#
# Your implementation of a tabular **Q-Learning** agent should produce a list named `q_learning_rewards`. This list should contain one list for each agent that you train. Each sub-list should contain the undiscounted sum of rewards earned during each episode by the corresponding agent. <br />
#
# Hint: Your Q-Learning implementation is likely to be similar to your Sarsa implementation. Think hard about where these two algorithms differ.

# %%
env = RacetrackEnv()

# Initialise/reset environment.
q_learning_rewards = []
𝛾 = 0.9
𝜖 = 0.15
𝛼 = 0.2
episodeNumber = 150
agentNumber = 20
print("Ready!")
# Out:
# Ready!

# %%
def chooseAction(Q, state):
    # using Q, derive action for current state
    # decide if explore action or greedy action
    if np.random.uniform(0, 1) < 𝜖:
        # explore action
        return np.random.randint(0, 9)
    # greedy action
    # loop through each action and find best action in current state
    QValues = []
    for i in range(9):
        QValues.append(Q[state, i])
    bestAction = QValues.index(max(QValues))
    return bestAction

# given a state, find the best (state, action) value
def maxAction(Q, state):
    QValues = []
    for i in range(9):
        QValues.append(Q[state, i])
    bestAction = QValues.index(max(QValues))
    return Q[state, bestAction]

for agent in range(agentNumber):
    print("New agent learning ", agent)
    # initalise agent variables (Q values)
    Q = defaultdict(float)
    q_learning_rewards.append([])
    for episode in range(episodeNumber):
        if episode % 10 == 0:
            print("Episode ", episode)
        q_learning_rewards[agent].append(0)
        state = env.reset()
        terminal = False
        # choose action from policy
        while terminal == False:
            action = chooseAction(Q, state)
            newState, reward, terminal = env.step(action)
            q_learning_rewards[agent][episode] += reward
            # update q value for state, action
            Q[state, action] = round(Q[state, action] + 𝛼*(reward + 𝛾*maxAction(Q, newState) - Q[state, action]), 2)
            #print("PrevState: ", state, "NewState: ", newState, "Reward: ", reward, "Action: ", action, "QValue: ", Q[state, action])
            state = newState
            
print("Fin")
# Out:
# New agent learning  0
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  1
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  2
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  3
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  4
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  5
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  6
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  7
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  8
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  9
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  10
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  11
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  12
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  13
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  14
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  15
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  16
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  17
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  18
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  19
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# Fin

# %%
from racetrack_env import plot_results
from racetrack_env import simple_issue_checking

# Checking Q-Learning Results for Obvious Issues.
simple_issue_checking(q_learning_rewards)

# Plotting Q-Learning Learning Curve.
# %matplotlib inline
plot_results(q_learning_rewards = q_learning_rewards)

# %% [markdown]
# ## Exercise 4: Comparison & Discussion (10 Marks)
#
# Below, we have used your results to plot your three previous learning curves on the same set of axes. <br />
# A cropped version of this learning curve has also been plotted, to make it easier to compare the performance of your agents towards the end of training.

# %%
from racetrack_env import plot_combined_results

# Plotting Combined Learning Curve.
# %matplotlib inline
plot_combined_results(mc_rewards, sarsa_rewards, q_learning_rewards)

# %% [markdown]
# Based on your results, and your understanding of the algorithms that you have implemented, please answer the following discussion questions. <br />
# Please do not exceed **two sentences** for any of your answers.
#
# **Question 1:** Briefly compare the performance of each of your agents.
#
# **Question 2:** Why do you think that your Monte Carlo and Temporal-Difference agents behaved differently?
#
# **Question 3:** Does the performance of your Sarsa and Q-Learning agents meet your expectations? Why do you think that this was the case?
#
# **Question 4:** What could be done to improve the performance of your agents?

# %% [markdown]
# Please write your answers for Exercise 4 in this markdown cell.
#
# **Answer 1:**
# The Q-learning agent is the first to reach a average return of -100, with the Monte Carlo and Sarsa agents reaching this same point in a similar number of episodes. The Q-learning agent continues to increase the return to a value around -25 for each episode; the Sarsa agent eventually reaches this value; the Monte Carlo agent fluctuates around the -100 return value.
#
# The runtime of the Monte Carlo agent was also significantly longer than the other agents. I believe it was caused by my implementation of first-visits which takes a long time when the episode consists of many time steps.
#
# **Answer 2:**
# One reason for this difference in behaviour is because the temporal-difference agent can begin learning straight away after a state transition, whereas the Monte Carlo agent must wait until the end of an episode before learning can take place. This is not huge issue when episodes are short however in this environment some episodes can last over 25,000 time steps which greatly slows down learning.
#
# **Answer 3:**
# I would expect the Sarsa agent to have a higher reward (since it will learn a 'safer' path through the environment that avoids the chance that exploratory actions could cause the agent to crashing), and the Q-learning agent to learn a more optimal policy but with less reward (since it does not consider the chance of exploratory actions which can cause it to crash when following the optimal policy). This is not the case (see learning curves), and I believe the performances are so different to what I expected as the environment returns a small reward for crashing (just -10) which does not outweigh the gain for reaching the goal state in less time steps.
#
#
# **Answer 4:**
# One improvement that could be done to the Sarsa agent is to implement the expected Sarsa algorithm. This is more complex algorithm however should perform slightly better than Sarsa as it uses the expected value and considers how likely each action is following the current policy.
#
# Another improvement that I could implement is to try different parameter values for the learning rate, discount factor and 𝜖-greedy explore action probability to gain better and more efficient learning performance.

# %% [markdown]
# ## Exercise 5: Modified Q-Learning Agent (18 Marks)
# ### Exercise 5a: Implementation
# In this exercise, you must implement a Temporal-Difference learning agent which learns to reach a goal state in the racetrack more efficiently than your previous Q-Learning agent. You may base your implementation on Q-Learning (Reinforcement Learning, Sutton & Barto, 2018, Section 6.5 p.131), the pseudocode for which is reproduced below, but you may also base your implementation on Sarsa if you wish.
#
# <img src="images/q_learning_algo.png" style="width: 650px;"/>
#
# In order to score high marks in this exercise, you will need to extend your solution beyond a simple Q-Learning or Sarsa agent to achieve higher performance and/or more efficient learning (i.e. using fewer interactions with the environment). Ideas for improving your agent will have been discussed in the unit, and can be found in the course textbook (Reinforcement Learning, Sutton & Barto, 2018). However you go about improving your agent, it must still use a **tabular** Temporal-Difference learning method at its core.
#
# Please use the following parameter settings:
# - Number of training episodes $= 150$.
# - Number of agents averaged should be at **least** 2.
#
#
# You may adjust all other parameters as you see fit.
#
#
# Your implementation of a tabular modified Temporal-Difference learning agent should produce a list named `modified_agent_rewards`. This list should contain one list for each agent that you train. Each sub-list should contain the undiscounted sum of rewards earned during each episode by the corresponding agent. <br />

# %%
env = RacetrackEnv()

# Initialise/reset environment.
modified_agent_rewards = []
𝛾 = 0.9
𝜖 = 0.15
𝛼 = 0.2
λ = 0.95 
episodeNumber = 150
agentNumber = 5
print("Ready!")
# Out:
# Ready!

# %%
# You should implement your modified q-learning agent agent and plot your average learning curve here.
# Following on from lectures, I will implement a SARSA(λ)
def chooseAction(Q, state):
    # using Q, derive action for current state
    if np.random.uniform(0, 1) < 𝜖:
        # explore action
        return np.random.randint(0, 9)
    # greedy action
    QValues = []
    for i in range(9): # loop through each action and find best action in current state
        QValues.append(Q[state, i])
    bestAction = QValues.index(max(QValues))
    return bestAction

for agent in range(agentNumber):
    print("New agent learning ", agent)
    # initialise agent variables
    Q = defaultdict(float)
    modified_agent_rewards.append([])
    for episode in range(episodeNumber):
        # reinitalise trace for each episode
        E = defaultdict(float)
        if episode % 10 == 0:
            print("Episode ", episode)
        modified_agent_rewards[agent].append(0)
        # initialise S and A
        state = env.reset()
        action = chooseAction(Q, state)
        terminal = False
        # choose action from policy
        while terminal == False:
            # take action, observe new state and reward
            newState, reward, terminal = env.step(action)
            modified_agent_rewards[agent][episode] += reward
            newAction = chooseAction(Q, newState)
            # calcualte TD error
            δ = reward + 𝛾*Q[newState, newAction] - Q[state, action]
            # increment E for state, action pair
            E[state, action] = E[state, action] + 1
            
            # for all state, actions
            for key in Q.keys():
                Q[key] = round(Q[key] + 𝛼*δ*E[key], 2)
                E[key] = round(𝛾*λ*E[key], 2)
            state = newState
            action = newAction
            
print("Fin")
# Out:
# New agent learning  0
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  1
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  2
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  3
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# New agent learning  4
# Episode  0
# Episode  10
# Episode  20
# Episode  30
# Episode  40
# Episode  50
# Episode  60
# Episode  70
# Episode  80
# Episode  90
# Episode  100
# Episode  110
# Episode  120
# Episode  130
# Episode  140
# Fin

# %% [markdown]
# ### Exercise 5b: Comparison & Discussion
#
# Below, we have used your results to plot a the performance of your modified agent and your previous Q-Learning agent on the same set of axes. <br />
# A cropped version of this learning curve has also been plotted, to make it easier to compare the performance of your agents towards the end of training.

# %%
from racetrack_env import plot_modified_agent_results
from racetrack_env import simple_issue_checking

# Checking Modified Agent Results for Obvious Issues.
simple_issue_checking(modified_agent_rewards, modified_agent = True)

# Plotting Modified Agent Learning Curve.
# %matplotlib inline
plot_modified_agent_results(q_learning_rewards, modified_agent_rewards)

# %% [markdown]
# Based on your results, and your understanding of the algorithm and modifications that you have implemented, please answer the following discussion questions. <br />
# Please do not exceed **two sentences** for any of your answers.
#
# **Question 1:** What modifications did you make to your agent?
#
# **Question 2:** What effect(s) did you expect your modifications to have on the performance of your agent?
#
# **Question 3:** Did your modifications have the effect(s) you expected? Why do you think that this was the case?
#
# **Question 4:** If you had more time, what would you do to further improve the performance of your agent?
#
# Please note that **your implementation and discussion will be assessed jointly**. This means that, in order to score highly, you will need to correctly implement appropriate modifications to your agent **AND** discuss them well.

# %% [markdown]
# Please write your answers for Exercise 5b in this markdown cell.
#
# **Answer 1:**
# I implemented the Sarsa(λ) algorithm which is an extension of the previously used Sarsa algorithm. It makes use of eligibility traces which helps keep a 'short term memory' of the states that have been visited.
#
# **Answer 2:**
# I expected the agent's learning efficiency to be improved (i.e. use less episodes to receive the same average return). I also expected some increase in runtime for the algorithm since it has to iterate over all states stored in Q for each state in each episode.
#
# **Answer 3:**
# The agent's learning efficiency did improve quite dramatically with it taking around 20 episodes less to converge to an average return of -100 compared to that of the Q-learning algorithm. This is the case because the state, action pairs which lead to a terminal state will be given increased reward (due to their eligibility trace) which helps speed up the agent's learning.
#
# The runtime of the algorithm was also impacted quite severely - the agent now takes several minutes to finish learning whereas previous algorithms took mere seconds. As mentioned, this was due to iterating over each state for every state in every episode.
#
# **Answer 4:**
# One improvement that I would like to add given additional time would be to implement an environment model that allows the agent to perform planning. This planning would be integrated with the learning and help to further improve the agent's performance.
